# %% [markdown]
# # Phase-1

# %% [markdown]
# # Data Collection/preparation part.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %% [markdown]
# **Between 2001 and 2012, India consisted of 28 States and 7 Union Territories.**

# %%
#list of STATES and UTs
STATE_UT = ['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA',
            'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA',
            'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU',
            'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
            'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY']

# %% [markdown]
# # 1. Collection of the population data for each state and union territory from the years 2001 to 2012.

# %% [markdown]
# **The population census, which is conducted every 10 years, provides data for the years 2001 and 2011. This means we only have information on the population for these two specific years.**

# %% [markdown]
# **Population data source link-wikipedia**

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population.

# %% [raw]
# State/UT           Population (2001)    Population (2011)
#
# Andhra Pradesh        75,728,400           84,664,012
# Arunachal Pradesh     1,098,328            1,383,727
# Assam                 26,638,600           31,169,272
# Bihar                 82,879,910           103,804,630
# Chhattisgarh          20,834,530           25,540,196
# Goa                   1,348,900            1,457,723
# Gujarat               50,597,200           60,383,628
# Haryana               21,083,900           25,753,081
# Himachal Pradesh      6,077,453            6,856,509
# Jammu & Kashmir       10,070,300           12,548,926
# Jharkhand             26,946,070           32,988,134
# Karnataka             52,734,986           61,130,704
# Kerala                31,839,000           33,387,677
# Madhya Pradesh        60,385,090           72,597,565
# Maharashtra           96,752,500           112,372,972
# Manipur               2,294,480            2,721,756
# Meghalaya             2,306,540            2,964,007
# Mizoram               889,690              1,091,014
# Nagaland              1,990,275            1,980,602
# Odisha                36,707,900           41,947,358
# Punjab                24,289,130           27,704,236
# Rajasthan             56,473,300           68,621,012
# Sikkim                541,902              607,688
# Tamil Nadu            62,111,390           72,138,958
# Tripura               3,191,880            3,671,032
# Uttar Pradesh         166,053,600          199,581,477
# Uttarakhand           8,489,100            10,116,752
# West Bengal           80,221,300           91,347,736
# A & N Islands         356,650              379,944
# Chandigarh            901,080              1,054,686
# D & N Haveli          220,963              342,853
# Daman & Diu           158,080              242,911
# Delhi                 13,851,503           16,753,235
# Lakshadweep           61,300               64,429
# Puducherry            974,820              1,244,464

# %%
# List containing the population data for each state and UT in year 2001
population_2001 = [75728400, 1098328, 26638600, 82879910, 20834530, 1348900, 50597200, 21083900, 6077453, 10070300, 26946070, 
                   52734986, 31839000, 60385090, 96752500, 2294480, 2306540, 889690, 1990275, 36707900, 24289130, 56473300, 
                   541902, 62111390, 3191880, 166053600, 8489100, 80221300, 356650, 901080, 220963, 158080, 13851503, 61300, 
                   974820]

# %%
# List containing the population data for each state and UT in year 2011
population_2011 = [84664012, 1383727, 31169272, 103804630, 25540196, 1457723, 60383628, 25753081, 6856509, 12548926, 32988134, 
                   61130704, 33387677, 72597565, 112372972, 2721756, 2964007, 1091014, 1980602, 41947358, 27704236, 68621012, 
                   607688, 72138958, 3671032, 199581477, 10116752, 91347736, 379944, 1054686, 342853, 242911, 16753235, 64429, 
                   1244464]

# %% [markdown]
# # 2. Collection of the literacy rate data for each state and union territory from the years 2001 to 2012.

# %% [markdown]
# **Literacy rate data source link-wikipedia**

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate

# %% [raw]
# State/UT        Literacy Rate (%) - 2001   Literacy Rate (%) - 2011
#
# Andhra Pradesh        60.47                      67.02
# Arunachal Pradesh     54.34                      65.38
# Assam                 63.25                      72.19
# Bihar                 47.00                      61.80
# Chhattisgarh          64.66                      70.28
# Goa                   82.01                      88.70
# Gujarat               69.14                      78.03
# Haryana               67.91                      75.55
# Himachal Pradesh      76.48                      82.80
# Jammu & Kashmir       55.52                      67.16
# Jharkhand             53.56                      66.41
# Karnataka             66.06                      75.36
# Kerala                90.86                      94.00
# Madhya Pradesh        63.74                      69.32
# Maharashtra           76.84                      82.34
# Manipur               70.50                      76.94
# Meghalaya             62.56                      74.43
# Mizoram               88.80                      91.33
# Nagaland              66.59                      79.55
# Odisha                63.08                      72.87
# Punjab                69.65                      75.84
# Rajasthan             60.41                      66.11
# Sikkim                68.81                      81.42
# Tamil Nadu            73.45                      80.33
# Tripura               73.19                      87.22
# Uttar Pradesh         56.27                      67.68
# Uttarakhand           71.62                      78.82
# West Bengal           68.64                      76.26
# A & N Islands         81.30                      86.63
# Chandigarh            81.94                      86.05
# D & N Haveli          57.63                      76.24
# Daman & Diu           78.18                      87.10
# Delhi                 81.67                      86.21
# Lakshadweep           86.66                      91.85
# Puducherry            81.24                      85.85

# %%
# List containing the literacy rate data for each state and UT in year 2001
literacy_rate_2001 = [60.47, 54.34, 63.25, 47.00, 64.66, 82.01, 69.14, 67.91, 76.48,55.52, 53.56, 66.06, 90.86, 63.74, 76.84, 
                      70.50, 62.56, 88.80, 66.59, 63.08, 69.65, 60.41, 68.81, 73.45, 73.19, 56.27, 71.62, 68.64, 81.3 , 81.94, 
                      57.63, 78.18, 81.67, 86.66, 81.24]

# %%
# List containing the literacy rate data for each state and UT in year 2011
literacy_rate_2011 = [67.02, 65.38, 72.19, 61.80, 70.28, 88.70, 78.03, 75.55, 82.80, 67.16, 66.41, 75.36, 94.00, 69.32, 82.34, 
                      76.94, 74.43, 91.33, 79.55, 72.87, 75.84, 66.11, 81.42, 80.33, 87.22, 67.68, 78.82, 76.26, 86.63, 86.05, 
                      76.24, 87.10, 86.21, 91.85, 85.85]

# %% [markdown]
# # 3. Collection of the area data for each state and union territory.

# %% [markdown]
# **Area data source link-wikipedia**

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area

# %% [raw]
# State/UT          Total Area (sq. km.)
#
# Andhra Pradesh        275,045
# Arunachal Pradesh     83,743
# Assam                 78,438
# Bihar                 94,163
# Chhattisgarh          135,192
# Goa                   3,702
# Gujarat               196,244
# Haryana               44,212
# Himachal Pradesh      55,673
# Jammu & Kashmir       222,236
# Jharkhand             79,716
# Karnataka             191,791
# Kerala                38,852
# Madhya Pradesh        308,252
# Maharashtra           307,713
# Manipur               22,327
# Meghalaya             22,429
# Mizoram               21,081
# Nagaland              16,579
# Odisha                155,707
# Punjab                50,362
# Rajasthan             342,239
# Sikkim                7,096
# Tamil Nadu            130,060
# Tripura               10,486
# Uttar Pradesh         240,928
# Uttarakhand           53,483
# West Bengal           88,752
# A & N Islands         8,249
# Chandigarh            114
# D & N Haveli          491
# Daman & Diu           111
# Delhi                 1,483
# Lakshadweep           30
# Puducherry            490

# %%
# List containing the data of area of each state and UT
area_sq_km = [275045,  83743,  78438,  94163, 135192,   3702, 196244,  44212, 55673, 222236,  79716, 191791,  38852, 308252, 
              307713,  22327, 22429,  21081,  16579, 155707,  50362, 342239, 7096, 130060, 10486, 240928,  53483,  88752, 8249,    114,    491,    111,
              1483, 30, 490]

# %%
# Storing the collected into the dataframe
df = pd.DataFrame({'STATE/UT': STATE_UT, 
                   'AREA (sq. km.)': area_sq_km, 
                   'POPULATION (2001)': population_2001, 
                   'POPULATION (2011)': population_2011,
                   'LITERACY RATE (%) - 2001': literacy_rate_2001,
                   'LITERACY RATE (%) - 2011': literacy_rate_2011})

# %%
df
# Out:
#              STATE/UT  AREA (sq. km.)  POPULATION (2001)  POPULATION (2011)  \
# 0      ANDHRA PRADESH          275045           75728400           84664012
# 1   ARUNACHAL PRADESH           83743            1098328            1383727
# 2               ASSAM           78438           26638600           31169272
# 3               BIHAR           94163           82879910          103804630
# 4        CHHATTISGARH          135192           20834530           25540196
# 5                 GOA            3702            1348900            1457723
# 6             GUJARAT          196244           50597200           60383628
# 7             HARYANA           44212           21083900           25753081
# 8    HIMACHAL PRADESH           55673            6077453            6856509
# 9     JAMMU & KASHMIR          222236           10070300           12548926
# 10          JHARKHAND           79716           26946070           32988134
# ...

# %% [markdown]
# # 4.collecting more information that will be useful for analysis later on.

# %% [markdown]
# **The dataset comprises population and literacy rate data only for the years 2001 and 2011. However, employing the linear interpolation method allows for the derivation of population and literacy rate data for all the remaining years.**

# %%
# Finding population for all other years with the help of linear interpolation

# Linear interpolation
start_year = 2001
end_year = 2011

# Calculate the annual change in population
df['Annual Change'] = (df['POPULATION (2011)'] - df['POPULATION (2001)']) / (end_year - start_year)

# Estimate population for intermediate years
intermediate_years = range(2002, 2013)
for year in intermediate_years:
    column_name = f'POPULATION ({year})'
    df[column_name] = (df['POPULATION (2001)'] + df['Annual Change'] * (year - start_year)).round()

# Drop the 'Annual Change' column
df.drop(columns = ['Annual Change'], axis = 1, inplace = True)

# %%
# Finding literacy rate for all other years with the help of linear interpolation

# Linear interpolation
start_year = 2001
end_year = 2011

# Calculate the annual change in literacy rate
df['Annual Change'] = (df['LITERACY RATE (%) - 2011'] - df['LITERACY RATE (%) - 2001']) / (end_year - start_year)

# Estimate literacy rates for intermediate years
intermediate_years = range(2002, 2013)
for year in intermediate_years:
    column_name = f'LITERACY RATE (%) - {year}'
    df[column_name] = (df['LITERACY RATE (%) - 2001'] + df['Annual Change'] * (year - start_year)).round(2)

# Drop the 'Annual Change' column
df.drop(columns = ['Annual Change'], axis = 1, inplace = True)

# %%
# Calculating the average population for each state and UT from 2001 to 2012
df['AVERAGE POPULATION (2001-2012)'] = df[['POPULATION (2001)', 'POPULATION (2002)', 'POPULATION (2003)', 'POPULATION (2004)',
                                           'POPULATION (2005)', 'POPULATION (2006)', 'POPULATION (2007)', 'POPULATION (2008)',
                                           'POPULATION (2009)', 'POPULATION (2010)', 'POPULATION (2011)', 'POPULATION (2012)'
                                            ]].mean(axis = 1).round()

# %%
# Calculating the average literacy rate for each state and UT from 2001 to 2012
df['AVERAGE LITERACY RATE (2001-2012)'] = df[['LITERACY RATE (%) - 2001', 'LITERACY RATE (%) - 2002', 'LITERACY RATE (%) - 2003', 
                                                  'LITERACY RATE (%) - 2004', 'LITERACY RATE (%) - 2005', 'LITERACY RATE (%) - 2006', 
                                                  'LITERACY RATE (%) - 2007', 'LITERACY RATE (%) - 2008', 'LITERACY RATE (%) - 2009', 
                                                  'LITERACY RATE (%) - 2010', 'LITERACY RATE (%) - 2011', 'LITERACY RATE (%) - 2012'
                                                  ]].mean(axis = 1).round(2)

# %%
# Calculating the population growth rate for each state and UT from 2001 to 2012
df['POPULATION GROWTH RATE (2001-2012)'] = (((df['POPULATION (2012)'] - df['POPULATION (2001)']) / df['POPULATION (2001)']) * 100).round()

# %%
df
# Out:
#              STATE/UT  AREA (sq. km.)  POPULATION (2001)  POPULATION (2011)  \
# 0      ANDHRA PRADESH          275045           75728400         84664012.0
# 1   ARUNACHAL PRADESH           83743            1098328          1383727.0
# 2               ASSAM           78438           26638600         31169272.0
# 3               BIHAR           94163           82879910        103804630.0
# 4        CHHATTISGARH          135192           20834530         25540196.0
# 5                 GOA            3702            1348900          1457723.0
# 6             GUJARAT          196244           50597200         60383628.0
# 7             HARYANA           44212           21083900         25753081.0
# 8    HIMACHAL PRADESH           55673            6077453          6856509.0
# 9     JAMMU & KASHMIR          222236           10070300         12548926.0
# 10          JHARKHAND           79716           26946070         32988134.0
# ...

# %%
df.to_csv('STATE_UT_POPULATION.csv', index = False)
